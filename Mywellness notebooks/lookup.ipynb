# %%
! pip install pandas
! pip install matplotlib
# Out:
# Requirement already satisfied: pandas in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.16/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_json("indooractivities-44efd75f-2b2f-44e2-a293-ec6caa3f836d-e146f083-60d0-4e78-b26e-dfc5f7cd45c2.json")
df.head()
# Out:
#                                    phId                                 on  \
# 0  a82fe9dd-a19d-4187-9ac8-334725cde149  2021-10-14T15:24:27.6064235+03:00
# 1  714de322-c075-4f87-8b5f-3e8ec01cf723  2021-10-14T15:31:36.5636004+03:00
# 2  a90dff63-b538-4f47-a5b9-df8bed8f78f0  2021-10-14T15:35:39.1494395+03:00
# 3  a72e7d8e-3660-499e-bf05-3c5f62278835  2021-10-14T15:37:41.7734113+03:00
# 4  ad18355c-dc5d-4fd3-bc84-c3c0196e4089  2021-10-14T15:46:04.1758463+03:00
#
#                                    user                              facility  \
# 0  44efd75f-2b2f-44e2-a293-ec6caa3f836d  9924c6d0-cce9-4c72-86ce-f2075aad8e8d
# 1  44efd75f-2b2f-44e2-a293-ec6caa3f836d  9924c6d0-cce9-4c72-86ce-f2075aad8e8d
# 2  44efd75f-2b2f-44e2-a293-ec6caa3f836d  9924c6d0-cce9-4c72-86ce-f2075aad8e8d
# 3  44efd75f-2b2f-44e2-a293-ec6caa3f836d  9924c6d0-cce9-4c72-86ce-f2075aad8e8d
# 4  44efd75f-2b2f-44e2-a293-ec6caa3f836d  9924c6d0-cce9-4c72-86ce-f2075aad8e8d
#
#                                        performedData  \
# 0  {'pr': [{'n': 'Duration', 'v': 348.0}, {'n': '...
# 1  {'pr': [{'n': 'Duration', 'v': 384.0}, {'n': '...
# 2  {'pr': [{'n': 'Duration', 'v': 240.0}, {'n': '...
# 3  {'pr': [{'n': 'Duration', 'v': 120.0}, {'n': '...
# 4  {'pr': [{'n': 'Duration', 'v': 360.0}, {'n': '...
#
#                       createdOn                                    id
# 0  2023-04-02T17:04:08.2975869Z  3a528e8c-4b1e-45d3-9a86-61876e705186
# 1  2023-04-02T17:04:08.2976623Z  81ac72bc-2061-48d9-8c5c-a574f811094d
# 2  2023-04-02T17:04:08.2977195Z  a088f2f9-79ca-4e8f-ac2f-912a6a4aa867
# 3  2023-04-02T17:04:08.2977676Z  e1a34c92-17ad-44a8-a166-777534181c50
# 4  2023-04-02T17:04:08.2977992Z  0e6f8ed1-9101-4af2-ada7-8645f1d95771

# %%
len(df.user.unique()) == 1 and len(df.facility.unique()) == 1
# Out:
# True

# %%
df = df.drop(columns=['facility','user'])
df.head()
# Out:
#                                    phId                                 on  \
# 0  a82fe9dd-a19d-4187-9ac8-334725cde149  2021-10-14T15:24:27.6064235+03:00
# 1  714de322-c075-4f87-8b5f-3e8ec01cf723  2021-10-14T15:31:36.5636004+03:00
# 2  a90dff63-b538-4f47-a5b9-df8bed8f78f0  2021-10-14T15:35:39.1494395+03:00
# 3  a72e7d8e-3660-499e-bf05-3c5f62278835  2021-10-14T15:37:41.7734113+03:00
# 4  ad18355c-dc5d-4fd3-bc84-c3c0196e4089  2021-10-14T15:46:04.1758463+03:00
#
#                                        performedData  \
# 0  {'pr': [{'n': 'Duration', 'v': 348.0}, {'n': '...
# 1  {'pr': [{'n': 'Duration', 'v': 384.0}, {'n': '...
# 2  {'pr': [{'n': 'Duration', 'v': 240.0}, {'n': '...
# 3  {'pr': [{'n': 'Duration', 'v': 120.0}, {'n': '...
# 4  {'pr': [{'n': 'Duration', 'v': 360.0}, {'n': '...
#
#                       createdOn                                    id
# 0  2023-04-02T17:04:08.2975869Z  3a528e8c-4b1e-45d3-9a86-61876e705186
# 1  2023-04-02T17:04:08.2976623Z  81ac72bc-2061-48d9-8c5c-a574f811094d
# 2  2023-04-02T17:04:08.2977195Z  a088f2f9-79ca-4e8f-ac2f-912a6a4aa867
# 3  2023-04-02T17:04:08.2977676Z  e1a34c92-17ad-44a8-a166-777534181c50
# 4  2023-04-02T17:04:08.2977992Z  0e6f8ed1-9101-4af2-ada7-8645f1d95771

# %%
# parse dates
df['on'] = pd.to_datetime(df['on'])
df['createdOn'] = pd.to_datetime(df['createdOn'])

# %%
df.phId.value_counts()
# Out:
# 050b6cd6-e178-e111-b0a2-001e4f3910c2    49
# 3f3bdb54-70c9-4a98-92ac-233deb04b257    48
# 0fb52d4e-0aab-4eb6-9537-25cb289858e0    37
# cb5c647c-fc08-4a64-a218-ef901d449c84    36
# 8948e10a-562b-4a9b-9769-9550a6485392    36
# 1f61fc3e-2a1d-4cfd-938c-c98c05297bbd    36
# 34ba6214-41fd-43ec-ad25-3737dbbb63e9    35
# 99781382-f068-4b08-a34c-d804fe3c77e3    34
# ad18355c-dc5d-4fd3-bc84-c3c0196e4089    32
# 976880a4-ac35-4864-ba99-8ff72f18df53    29
# 28fcb928-c1dc-4da1-b276-7b50c9a47224    28
# b3264101-00c6-48f4-868a-f45e7aac92a9    26
# 290b6cd6-e178-e111-b0a2-001e4f3910c2    24
# 020b6cd6-e178-e111-b0a2-001e4f3910c2    24
# ad2f1740-9a45-447f-b974-c57ddb90c105    23
# 0c131ba3-4cfc-493b-a5c3-7f2b7b0a6754    23
# 41d91ea5-7e32-4232-bf46-3730a033e9c5    22
# 7276fc73-ad5c-478e-a8d2-7a839801f4b0    22
# 455b56eb-42e8-40ed-8373-00e5fae67599    21
# e248b03f-fd70-4324-a95f-d83d847db460    21
# 4039eefb-2fda-44a2-9eda-00a224129733    21
# 9ff7329b-d804-4663-a558-a26467198c71    20
# 39fd1ae8-c8a6-4937-90a4-1f45fbc20a4d    19
# 9b9ea13f-6e86-4c9d-8598-4b0c22c13398    19
# ac12b900-b8a8-410c-b8d3-c1fc6321f266    19
# 714de322-c075-4f87-8b5f-3e8ec01cf723    19
# 920b716c-17fb-4bda-8670-cbd4748863b4    19
# a90dff63-b538-4f47-a5b9-df8bed8f78f0    19
# a82fe9dd-a19d-4187-9ac8-334725cde149    19
# 0da34761-c695-49f2-bc20-bc5b409a7c21    18
# 70665f74-c8d9-4890-ade9-335d88d055bd    17
# 650b6cd6-e178-e111-b0a2-001e4f3910c2    13
# a72e7d8e-3660-499e-bf05-3c5f62278835     8
# c49cc92e-e178-e111-b0a2-001e4f3910c2     6
# a69e4ead-36f7-46a9-beea-37984e118353     5
# 740b6cd6-e178-e111-b0a2-001e4f3910c2     5
# 6a0b6cd6-e178-e111-b0a2-001e4f3910c2     4
# ff148b74-c946-4f81-8ff1-113631dbee97     3
# 054c1d5d-485c-4668-8459-311ca389edec     3
# 44cad859-516b-4bdf-863b-2c23493f168f     2
# e8706b12-d878-e111-b0a2-001e4f3910c2     1
# fa0a6cd6-e178-e111-b0a2-001e4f3910c2     1
# 8da6ceb4-d036-49e0-8b55-b86edc77e82e     1
# 77f3aff1-ece5-420c-b904-ae200766e76a     1
# 250b6cd6-e178-e111-b0a2-001e4f3910c2     1
# a76790df-9da2-4d1a-bd06-830a315cd849     1
# dd4b38a7-5fac-4973-81fd-a8c4d8a64a57     1
# 026a2ebe-c793-40a7-a3f4-0f5f86067059     1
# b7d0c354-7f85-403e-9056-16bf4ee2962d     1
# 1b1588b3-2408-4e6a-b3a0-9f5f640557a7     1
# 0da60f38-e451-4e80-a45c-bc3fc35b4d93     1
# 9a65c08c-73ea-45a3-83cc-3e5bd6e5774e     1
# 46cfc136-524e-47d0-8188-888a056c15d7     1
# Name: phId, dtype: int64

# %%
df[df.phId == '050b6cd6-e178-e111-b0a2-001e4f3910c2']['performedData'].values[0]
# Out:
# {'pr': [{'n': 'Duration', 'v': 105.0},
#   {'n': 'Move', 'v': 22.415131},
#   {'n': 'MetsMin', 'v': 4.611113},
#   {'n': 'Calories', 'v': 12.276},
#   {'n': 'TotalIsoWeight', 'v': 265.0},
#   {'n': 'Rm1', 'v': 28.65095}],
#  'st': [{'pos': 0,
#    'pr': [{'n': 'IsoReps', 'v': 1.0},
#     {'n': 'RestTime', 'v': 4.0},
#     {'n': 'Duration', 'v': 1.0},
#     {'n': 'IsoWeight', 'v': 2.5}]},
#   {'pos': 0,
#    'pr': [{'n': 'IsoReps', 'v': 15.0},
#     {'n': 'RestTime', 'v': 60.0},
#     {'n': 'Duration', 'v': 40.0},
#     {'n': 'IsoWeight', 'v': 17.5}]}]}

# %%
def single_set_convert(input_dict,**kwarg):
    assert input_dict['pos'] == 0
    result = kwarg
    for entry in input_dict['pr']:
        result[entry['n']] = entry['v']
    return result

def multiple_sets_convert(multiple_dicts):
    return [single_set_convert(entry,order=index) for index,entry in enumerate(multiple_dicts)]

def convert_exercise(entry):
    assert 'pr' in entry.keys() and 'st' in entry.keys()
    return multiple_sets_convert(entry['st'])

df['performedData'] = df['performedData'].apply(convert_exercise)

# %%
df['performedData'][0]
# Out:
# [{'order': 0,
#   'IsoReps': 10.0,
#   'Duration': 60.0,
#   'IsoWeight': 50.0,
#   'RestTime': 60.0,
#   'Power': 0.0,
#   'Perc1Rm': 1.0},
#  {'order': 1,
#   'IsoReps': 10.0,
#   'Duration': 60.0,
#   'IsoWeight': 50.0,
#   'RestTime': 60.0,
#   'Power': 0.0,
#   'Perc1Rm': 1.0},
#  {'order': 2,
#   'IsoReps': 8.0,
#   'Duration': 48.0,
#   'IsoWeight': 50.0,
#   'RestTime': 60.0,
#   'Power': 0.0,
#   'Perc1Rm': 1.0}]

# %%
exercises_types =  df.drop_duplicates(subset=["phId"], keep='first')
exercises_types['performedDataStoredValues']  = exercises_types['performedData'].apply(lambda x: str(sorted(x[0].keys())) if len(x) > 0 else None)
exercises_types['performedDataStoredValues'].value_counts()
# Out:
# /tmp/ipykernel_1477/423339661.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exercises_types['performedDataStoredValues']  = exercises_types['performedData'].apply(lambda x: str(sorted(x[0].keys())) if len(x) > 0 else None)
# ['Duration', 'IsoReps', 'IsoWeight', 'Perc1Rm', 'Power', 'RestTime', 'order']    24
# ['Duration', 'IsoReps', 'RestTime', 'order']                                     13
# ['Duration', 'IsoReps', 'IsoWeight', 'RestTime', 'order']                         6
# ['AvgHr', 'Duration', 'order']                                                    3
# ['AvgHr', 'Calories', 'Duration', 'HDistance', 'Move', 'Speed', 'order']          1
# ['AvgHr', 'Duration', 'Level', 'order']                                           1
# ['AvgHr', 'Calories', 'Duration', 'HDistance', 'Level', 'Move', 'order']          1
# Name: performedDataStoredValues, dtype: int64

# %%
exercises_types['Isweights'] = exercises_types['performedDataStoredValues'].apply(lambda x:True if x and 'IsoWeight' in x else False)
weights_phId = exercises_types[exercises_types['Isweights']]['phId']
# Out:
# /tmp/ipykernel_1477/1541232237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exercises_types['Isweights'] = exercises_types['performedDataStoredValues'].apply(lambda x:True if x and 'IsoWeight' in x else False)

# %%
weights_phId
# Out:
# 0      a82fe9dd-a19d-4187-9ac8-334725cde149
# 1      714de322-c075-4f87-8b5f-3e8ec01cf723
# 2      a90dff63-b538-4f47-a5b9-df8bed8f78f0
# 4      ad18355c-dc5d-4fd3-bc84-c3c0196e4089
# 5      050b6cd6-e178-e111-b0a2-001e4f3910c2
# 7      3f3bdb54-70c9-4a98-92ac-233deb04b257
# 9      290b6cd6-e178-e111-b0a2-001e4f3910c2
# 10     ac12b900-b8a8-410c-b8d3-c1fc6321f266
# 11     9b9ea13f-6e86-4c9d-8598-4b0c22c13398
# 12     70665f74-c8d9-4890-ade9-335d88d055bd
# 20     fa0a6cd6-e178-e111-b0a2-001e4f3910c2
# 149    c49cc92e-e178-e111-b0a2-001e4f3910c2
# 153    e8706b12-d878-e111-b0a2-001e4f3910c2
# 176    250b6cd6-e178-e111-b0a2-001e4f3910c2
# 222    dd4b38a7-5fac-4973-81fd-a8c4d8a64a57
# 223    026a2ebe-c793-40a7-a3f4-0f5f86067059
# 224    b7d0c354-7f85-403e-9056-16bf4ee2962d
# 225    1b1588b3-2408-4e6a-b3a0-9f5f640557a7
# 226    46cfc136-524e-47d0-8188-888a056c15d7
# 227    0da60f38-e451-4e80-a45c-bc3fc35b4d93
# 228    9a65c08c-73ea-45a3-83cc-3e5bd6e5774e
# 236    4039eefb-2fda-44a2-9eda-00a224129733
# 237    e248b03f-fd70-4324-a95f-d83d847db460
# 239    455b56eb-42e8-40ed-8373-00e5fae67599
# 240    1f61fc3e-2a1d-4cfd-938c-c98c05297bbd
# 242    0c131ba3-4cfc-493b-a5c3-7f2b7b0a6754
# 243    7276fc73-ad5c-478e-a8d2-7a839801f4b0
# 244    976880a4-ac35-4864-ba99-8ff72f18df53
# 246    020b6cd6-e178-e111-b0a2-001e4f3910c2
# 261    41d91ea5-7e32-4232-bf46-3730a033e9c5
# Name: phId, dtype: object

# %%
weights_df = df[df['phId'].isin(weights_phId.values)]

def max_lifted(sets):
    return max(map(lambda x:x['IsoWeight'],sets))

def total_lifted(sets):
    return sum(map(lambda x:x['IsoWeight'],sets))

def number_of_sets(sets):
    return len(sets)


weights_df["max_lifted"] = weights_df['performedData'].apply(max_lifted)
weights_df["total_lifted"] = weights_df['performedData'].apply(total_lifted)
weights_df["number_of_sets"] = weights_df['performedData'].apply(number_of_sets)
weights_df.head()
# Out:
# /tmp/ipykernel_1477/222472866.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weights_df["max_lifted"] = weights_df['performedData'].apply(max_lifted)
# /tmp/ipykernel_1477/222472866.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weights_df["total_lifted"] = weights_df['performedData'].apply(total_lifted)
# /tmp/ipykernel_1477/222472866.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weights_df["number_of_sets"] = weights_df['performedData'].apply(number_of_sets)
#                                    phId                                on  \
# 0  a82fe9dd-a19d-4187-9ac8-334725cde149  2021-10-14 15:24:27.606423+03:00
# 1  714de322-c075-4f87-8b5f-3e8ec01cf723  2021-10-14 15:31:36.563600+03:00
# 2  a90dff63-b538-4f47-a5b9-df8bed8f78f0  2021-10-14 15:35:39.149439+03:00
# 4  ad18355c-dc5d-4fd3-bc84-c3c0196e4089  2021-10-14 15:46:04.175846+03:00
# 5  050b6cd6-e178-e111-b0a2-001e4f3910c2  2021-10-14 15:49:43.574302+03:00
#
#                                        performedData  \
# 0  [{'order': 0, 'IsoReps': 10.0, 'Duration': 60....
# 1  [{'order': 0, 'IsoReps': 12.0, 'Duration': 72....
# 2  [{'order': 0, 'IsoReps': 10.0, 'Duration': 60....
# 4  [{'order': 0, 'IsoReps': 10.0, 'Duration': 60....
# 5  [{'order': 0, 'IsoReps': 1.0, 'RestTime': 4.0,...
#
#                             createdOn                                    id  \
# 0 2023-04-02 17:04:08.297586900+00:00  3a528e8c-4b1e-45d3-9a86-61876e705186
# 1 2023-04-02 17:04:08.297662300+00:00  81ac72bc-2061-48d9-8c5c-a574f811094d
# 2 2023-04-02 17:04:08.297719500+00:00  a088f2f9-79ca-4e8f-ac2f-912a6a4aa867
# 4 2023-04-02 17:04:08.297799200+00:00  0e6f8ed1-9101-4af2-ada7-8645f1d95771
# 5 2023-04-02 17:04:08.297855500+00:00  4d8b9dc4-7cf0-4e3f-9180-a475fe6af52c
#
#    max_lifted  total_lifted  number_of_sets
# 0        50.0         150.0               3
# 1        14.0          40.0               3
# 2        10.0          20.0               2
# 4        40.0         120.0               3
# 5        17.5          20.0               2

# %%
weights_df.groupby('phId').plot(y='total_lifted',x='createdOn',kind='line')
# Out:
# /workspace/.pyenv_mirror/user/current/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:512: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# phId
# 020b6cd6-e178-e111-b0a2-001e4f3910c2    Axes(0.125,0.2;0.775x0.68)
# 026a2ebe-c793-40a7-a3f4-0f5f86067059    Axes(0.125,0.2;0.775x0.68)
# 050b6cd6-e178-e111-b0a2-001e4f3910c2    Axes(0.125,0.2;0.775x0.68)
# 0c131ba3-4cfc-493b-a5c3-7f2b7b0a6754    Axes(0.125,0.2;0.775x0.68)
# 0da60f38-e451-4e80-a45c-bc3fc35b4d93    Axes(0.125,0.2;0.775x0.68)
# 1b1588b3-2408-4e6a-b3a0-9f5f640557a7    Axes(0.125,0.2;0.775x0.68)
# 1f61fc3e-2a1d-4cfd-938c-c98c05297bbd    Axes(0.125,0.2;0.775x0.68)
# 250b6cd6-e178-e111-b0a2-001e4f3910c2    Axes(0.125,0.2;0.775x0.68)
# 290b6cd6-e178-e111-b0a2-001e4f3910c2    Axes(0.125,0.2;0.775x0.68)
# 3f3bdb54-70c9-4a98-92ac-233deb04b257    Axes(0.125,0.2;0.775x0.68)
# 4039eefb-2fda-44a2-9eda-00a224129733    Axes(0.125,0.2;0.775x0.68)
# 41d91ea5-7e32-4232-bf46-3730a033e9c5    Axes(0.125,0.2;0.775x0.68)
# 455b56eb-42e8-40ed-8373-00e5fae67599    Axes(0.125,0.2;0.775x0.68)
# 46cfc136-524e-47d0-8188-888a056c15d7    Axes(0.125,0.2;0.775x0.68)
# 70665f74-c8d9-4890-ade9-335d88d055bd    Axes(0.125,0.2;0.775x0.68)
# 714de322-c075-4f87-8b5f-3e8ec01cf723    Axes(0.125,0.2;0.775x0.68)
# 7276fc73-ad5c-478e-a8d2-7a839801f4b0    Axes(0.125,0.2;0.775x0.68)
# 976880a4-ac35-4864-ba99-8ff72f18df53    Axes(0.125,0.2;0.775x0.68)
# 9a65c08c-73ea-45a3-83cc-3e5bd6e5774e    Axes(0.125,0.2;0.775x0.68)
# 9b9ea13f-6e86-4c9d-8598-4b0c22c13398    Axes(0.125,0.2;0.775x0.68)
# a82fe9dd-a19d-4187-9ac8-334725cde149    Axes(0.125,0.2;0.775x0.68)
# a90dff63-b538-4f47-a5b9-df8bed8f78f0    Axes(0.125,0.2;0.775x0.68)
# ac12b900-b8a8-410c-b8d3-c1fc6321f266    Axes(0.125,0.2;0.775x0.68)
# ad18355c-dc5d-4fd3-bc84-c3c0196e4089    Axes(0.125,0.2;0.775x0.68)
# b7d0c354-7f85-403e-9056-16bf4ee2962d    Axes(0.125,0.2;0.775x0.68)
# c49cc92e-e178-e111-b0a2-001e4f3910c2    Axes(0.125,0.2;0.775x0.68)
# dd4b38a7-5fac-4973-81fd-a8c4d8a64a57    Axes(0.125,0.2;0.775x0.68)
# e248b03f-fd70-4324-a95f-d83d847db460    Axes(0.125,0.2;0.775x0.68)
# e8706b12-d878-e111-b0a2-001e4f3910c2    Axes(0.125,0.2;0.775x0.68)
# fa0a6cd6-e178-e111-b0a2-001e4f3910c2    Axes(0.125,0.2;0.775x0.68)
# dtype: object
